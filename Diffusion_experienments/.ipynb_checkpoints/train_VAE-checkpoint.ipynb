# %%
from preprocessing import *
from encoder import Encoder
from decoder import Decoder
import torch.optim as optim

encoder = Encoder() # input 64*64 image, output 128 feacture vector
decoder = Decoder() # input 128 feature vector, output 64*64 image

# %%
def train_VAE_1ep(encoder, decoder, optimizer_e, optimizer_d, epoch):  
#     gan_input = torch.normal(0, 1, size=(1,1,64, 64)) # noise
    encoder.train()
    decoder.train()
    ep_loss = 0
    for i in range(train_data.shape[0]):
        optimizer_e.zero_grad()
        optimizer_d.zero_grad()
        z = torch.sum((train_data[i] - decoder(encoder(train_data[i])))**2)
        loss=z
        loss.backward()
        optimizer_e.step()
        optimizer_d.step()
        ep_loss += loss.item()
    tensor_to_picture(decoder(encoder(train_data[200])).detach().numpy()[0][0])
    
    return ep_loss/train_data.shape[0]

# %%
def train_VAE(eps, lr, reg, lr_decay):
    for epoch in range(eps): 
        optimizer_e = optim.SGD(encoder.parameters(), lr=lr*lr_decay**epoch, momentum=0.9, weight_decay=reg, nesterov=False)
        optimizer_d = optim.SGD(decoder.parameters(), lr=lr*lr_decay**epoch, momentum=0.9, weight_decay=reg, nesterov=False)
        epoch_loss = train_VAE_1ep(encoder, decoder, optimizer_e, optimizer_d, epoch)
        print("loss(generator): ", epoch_loss)

# %%
train_VAE(30, 0.00001, 0.0001, 0.99)
# Out:
# loss(generator):  2596.2849670410155
# loss(generator):  2244.4556344604493
# loss(generator):  2076.0578800964354
# loss(generator):  1908.719559173584
# loss(generator):  1865.506582183838
# loss(generator):  1846.9225247192383
# loss(generator):  1780.8666076660156
# loss(generator):  1798.975948791504
# loss(generator):  1719.9781175231933
# loss(generator):  1663.414640197754
# loss(generator):  1657.4520545959472
# loss(generator):  1654.6594831848145
# loss(generator):  1596.55486328125
# loss(generator):  1565.17397064209
# loss(generator):  1582.507932434082
# loss(generator):  1577.9868545532227
# loss(generator):  1585.1109356689453
# loss(generator):  1571.62705368042
# loss(generator):  1578.514725189209
# loss(generator):  1560.244562072754
# loss(generator):  1529.7431095886232
# loss(generator):  1492.2986006164551
# loss(generator):  1470.3293264770507
# loss(generator):  1437.3443574523926
# loss(generator):  1425.4756225585938
# loss(generator):  1415.003130645752
# ...

# %%
train_VAE(10, 0.00001, 0.0001, 0.99)
# Out:
# loss(generator):  1458.0689715576173
# loss(generator):  1452.3469448852538
# loss(generator):  1466.1609680175782
# loss(generator):  1450.5924479675293
# loss(generator):  1488.6630535888671
# loss(generator):  1470.7823068237306
# loss(generator):  1464.9796467590331
# loss(generator):  1471.2769007873535
# loss(generator):  1464.510281982422
# loss(generator):  1467.7733889770507

# %%
train_VAE(50, 0.000001, 0.000001, 0.99)
# Out:
# loss(generator):  1268.0187355041503
# loss(generator):  1266.4929801940918
# loss(generator):  1264.892349243164
# loss(generator):  1263.3897604370118
# loss(generator):  1261.9328038024903
# loss(generator):  1260.4982160949708
# loss(generator):  1259.0832473754883
# loss(generator):  1257.7304867553712
# loss(generator):  1256.4311669921874
# loss(generator):  1255.134951171875
# loss(generator):  1253.855016555786
# loss(generator):  1252.6297145080566
# loss(generator):  1251.4175324249268
# loss(generator):  1250.2518885803222
# loss(generator):  1249.1112519836427
# loss(generator):  1248.0148028564454
# loss(generator):  1246.9282015991212
# loss(generator):  1245.9056799316406
# loss(generator):  1244.8617631530763
# loss(generator):  1243.8712937164307
# loss(generator):  1242.9093990325928
# loss(generator):  1241.9776906585694
# loss(generator):  1241.0528437805176
# loss(generator):  1240.1594746398926
# loss(generator):  1239.2722956848145
# ...

# %%
tensor_to_picture(train_data[200].detach().numpy()[0][0])

# %%
tensor_to_picture(decoder(encoder(train_data[199])).detach().numpy()[0][0])

# %%
tensor_to_picture(train_data[199].detach().numpy()[0][0])

# %%
tensor_to_picture(decoder(encoder(train_data[198])).detach().numpy()[0][0])

# %%
tensor_to_picture(train_data[198].detach().numpy()[0][0])

# %%
for i in range(10):
    dual = decoder(0.1*i*encoder(train_data[198])+0.1*(10-i)*encoder(train_data[199])).detach().numpy()[0][0]
    tensor_to_picture(dual)
