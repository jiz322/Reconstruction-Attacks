# %%
from preprocessing import *

# %%
from encoder import Encoder
from decoder import Decoder

# %%
encoder = Encoder() # input 64*64 image, output 128 feacture vector
decoder = Decoder() # input 128 feature vector, output 64*64 image

# %%
tensor_to_picture(decoder(encoder(train_data[0])).detach().numpy()[0][0])

# %%
train_data[0] - decoder(encoder(train_data[0]))
# Out:
# tensor([[[[-0.5188, -0.2031, -0.3308,  ..., -1.4002, -1.0990, -1.0072],
#           [-0.3158, -0.1349, -0.2548,  ..., -1.5731, -0.9019, -0.9884],
#           [-0.2152,  0.0498, -0.0944,  ..., -1.4575, -1.2501, -1.2094],
#           ...,
#           [-2.1865, -2.2200, -2.2205,  ..., -0.2580, -0.2599, -0.2474],
#           [-1.7708, -1.4630, -1.5542,  ..., -0.0727, -0.3121, -0.2750],
#           [ 0.2039,  0.2808,  0.2740,  ..., -0.1241, -0.1551, -0.1657]]]],
#        grad_fn=<SubBackward0>)
